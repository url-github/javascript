# %% [markdown]
# ![2021-12-10 08_18_19-script.js - JavaScript - Visual Studio Code.png](data:image/png;base64,...)

# %% [markdown]
# 71. Pobieranie elementów na stronie cz.1

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>
    <h1>DOM, Document, Window...</h1>

<!-- <ul style='margin-top: 100px; margin-left: 100px;'> -->

    <li id='item'>To li ma ID</li>
    <li>li bez klasy oraz ID</li>
    <li class='test'>to li ma klasę</li>
    <li class='test'>to li ma klasę</li>
    <li>li bez klasy oraz ID</li>

<!-- </ul> -->

    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}

# %%
// getElementById

const test = document.getElementById('item')
console.log(test)

// getElementsByTagName

const test2 = document.getElementsByTagName('li')
console.log(test2)

// getElementsByClassName

const test3 = document.getElementsByClassName('test')
console.log(test3)

# %% [markdown]
# 72. Pobieranie elementów na stronie cz.2 [EC6]

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>
    <h1>DOM, Document, Window...</h1>

<ul style='margin-top: 100px; margin-left: 100px;'>

    <li id='item'>To li ma ID</li>
    <li>li bez klasy oraz ID</li>
    <li class='test'>to li ma klasę</li>
    <li class='test'>to li ma klasę</li>
    <li>li bez klasy oraz ID</li>

</ul>

    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}

# %%
// Pobiera pierwszy napotkany li
const test = document.querySelector('li')
console.log(test)


// Pobieranie ID
const test2 = document.querySelector('#item')
console.log(test)

// Zapis jest taki sam jak w css
const test3 = document.querySelector('ul li')
console.log(test3)

const ulList = document.querySelector('ul')
console.log(ulList)

const liItem = ulList.querySelector('li')
console.log(liItem)


// querySelectorAll (ES6)
const test5 = document.querySelectorAll('ul li')
console.log(test5)

const liItems = document.querySelectorAll('li.test')
console.log(liItems)

// // querySelector i querySelectorAll nie wspiera żywych kolekcji
// // czyli dynamicznie dodawanych elementów za pomocą JS vs getElementsByTag / ClassName


// W tym miejscu dodaje dynamicznie li - google analytics
const newLi = document.createElement('li')
ulList.appendChild(newLi).textContent = 'google analytics'
console.log(liItems.length)


const dynamic = document.getElementsByTagName('li')
console.log(dynamic.length)

# %% [markdown]
# Zadanie z pobierania elementów

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>
    <h1>pobierz mnie do zmiennej 'heading'</h1>
    <p>pobierz mnie do elementu tablico-podobnego razem z innymi paragrafami!</p>
    <p>pobierz mnie do elementu tablico-podobnego razem z innymi paragrafami!</p>
    <p>pobierz mnie do elementu tablico-podobnego razem z innymi paragrafami!</p>
    <div class="test">
        <p>pobierz DIV-a z klasą test do jakiejś zmiennej</p>
        <p id="test">następnie pobierz ten paragraf, ale nie przeszukuj całego `document`, przeszukaj tylko DIV-a z klasą test</p>
    </div>

    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}

# %%
const heading = document.querySelector('h1')
console.log(heading)

const allP = document.querySelectorAll('p') // zwracam uwagę na słowo 'All' 😉
console.log(allP)

const testDiv = document.querySelector('.test')
console.log(testDiv)

const pInsideDiv = testDiv.querySelector('#test')
console.log(pInsideDiv)

# %% [markdown]
# 75. Tworzenie i dodawanie elementów na stronie

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>

    <div></div>
    <h1>DOM, Document, Window...</h1> 
   
    <script src="./script.js"></script>
</body>
</html>

# %%
const ulList = document.createElement('ul')
// console.log(ulList)

const liItem = document.createElement('li')
// console.log(liItem)

ulList.textContent = 'JavaScript'
liItem.textContent = 'Python'

document.body.appendChild(ulList)
document.body.appendChild(liItem)

console.log(document.body)

const div = document.querySelector('div')
const p = document.createElement('p')
div.appendChild(p)

# %% [markdown]
# 76. append & appendChild

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"
</head>

<body>

    <div></div>
    <h1>DOM, Document, Window...</h1> 
   
    <script src="./script.js"></script>
</body>
</html>

# %%
const div = document.querySelector('div')
const p = document.createElement('p')
const headingTwo = document.createElement('h2')

// div.appendChild(p)
// div.appendChild(headingTwo)

div.append(p, headingTwo)

# %% [markdown]
# 77. textContent, innerText, outerHTML & innerHTML

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
</head>

<body>
    <h1>DOM, Document, Window...</h1>
    <!-- <button>Przycisk</button>

    <p class="inner-text">
        to
        <span style="display: none;">jest</span>
        <style>p {font-size: 22px;}</style>
        innerText
    </p>

    <p class="text-content">
        to
        <span style="display: none;">jest</span>
        <style>p {font-size: 22px;}</style>
        textContent
    </p> -->

    <input type='text'>
    <p class='under-input'>Tekst pod inputem</p>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
const btn = document.querySelector('button')

console.log(btn.outerHTML)
console.log(btn.innerHTML)

btn.outerHTML = 'Pandas'
btn.innerHTML = 'JavaScipt'

document.body.innerHTML = ''

console.log(btn.innerText)
console.log(btn.textContent)

btn.textContent = 'abcd'
btn.innerText = 'abcd!'

const innerT = document.querySelector('.inner-text')
const textC = document.querySelector('.text-content')

console.log(innerT.innerText)
console.log(textC.textContent)

const input = document.querySelector('input')

const underInput = document.querySelector('.under-input')

input.addEventListener('keydown', e => {
    if(e.key === 'Enter') {

        underInput.innerHTML = input.value // Nie można stosować innerHTML, bo można ingerować w kod wprowadzając kod w inputa

        // underInput.textContent = input.value
    }
})

# %% [markdown]
# 78. Usuwanie elementów

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
</head>

<body>
    <h1>DOM, Document, Window...</h1>
   
    <div>
        <p>test</p>
    </div>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
const div = document.querySelector('div')
// console.log(div)

const p = document.querySelector('p')
// console.log(p)

// removeChild

// div.removeChild(p)
// document.body.removeChild(div)

// remove

p.remove()
div.remove()

# %% [markdown]
# 79. Addeventlistener

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
</head>

<body>
    <h1>DOM, Document, Window...</h1>
   
    <div>
        <button class='btn btn-1'>Kliknięto mnie!</button>
        <button class='btn btn-2'>Najechano na mnie...</button>
        <button class='btn btn-3'>double click</button>        
    </div>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
// target.addEventListener(type, listener)

// const btn1 = document.querySelector('.btn-1')
// const btn2 = document.querySelector('.btn-2')
// const btn3 = document.querySelector('.btn-3')

// btn1.addEventListener('click', function (){
//     console.log('Kliknięto mnie!');
// })

// btn2.addEventListener('mouseover', () => console.log('Najechano na mnie'))

// const test = () => {
//     console.log('double click');
// }

// btn3.addEventListener('dblclick', test)
// btn1.addEventListener('click', test)

const btns = document.querySelectorAll('button')
console.log(btns)

const python = () => {
    console.log('Python')
}

btns.forEach(btn => btn.addEventListener('click', python))

# %% [markdown]
# 80. Addeventlistener

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
</head>

<body>
    <h1>DOM, Document, Window...</h1>
   
    <button class='test info btn abcd'>Jestem przyciskiem</button>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
const btn = document.querySelector('button')

const test = (e) => {
    console.log(e)
    console.log(e.target)
    console.log(e.target.classList)
    console.log(e.target.offsetTop)
}

btn.addEventListener('click', test)

# %% [markdown]
# 81. Bubbling & capturing

# %% [markdown]
# ![2021-12-12 15_48_04-UI Events.png](data:image/png;base64,...)

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
 
</head>

<body>
    <h1>DOM, Document, Window...</h1>

   
    <div>
        <div class='circle lime'>
            <div class='circle blue'>
                <div class='circle gold'></div>
            </div>
        </div>
    </div>

    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}


.gold {
    position: absolute;
    top: 50%;
    transform: translate(-50%, -50%);
    background-color: gold;
    width: 100px;
    height: 100px;
}

# %%
const lime = document.querySelector('.lime')
const blue = document.querySelector('.blue')
const gold = document.querySelector('.gold')

const infoLime = () => {
    console.log('%clime', 'color: lime; text-transform: uppercase')
}

const infoBlue = () => {
    console.log('%cblue', 'color: royalblue; text-transform: uppercase')
}

const infoGold = () => {
    console.log('%cgold', 'color: gold; text-transform: uppercase')
}


// Domyślnie jest Bubbling Phase
lime.addEventListener('click', infoLime)
blue.addEventListener('click', infoBlue)
gold.addEventListener('click', infoGold)

// Teraz mam Capture Phase
lime.addEventListener('click', infoLime, {capture: true})
blue.addEventListener('click', infoBlue,{capture: true})
gold.addEventListener('click', infoGold, {capture: true})

# %% [markdown]
# 82. stopPropagation

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
 
</head>

<body>
    <h1>DOM, Document, Window...</h1>

   
    <div>
        <div class='circle lime'>
            <div class='circle blue'>
                <div class='circle gold'></div>
            </div>
        </div>
    </div>

    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}


.gold {
    position: absolute;
    top: 50%;
    transform: translate(-50%, -50%);
    background-color: gold;
    width: 100px;
    height: 100px;
}

# %%
const blue = document.querySelector('.blue')
const gold = document.querySelector('.gold')

const infoBlue = () => {
    console.log('%cten kod nie miał się teraz wykonać', 'color: royalblue; text-transform: uppercase')
}

const infoGold = (e) => {
    e.stopPropagation()
    console.log('%cwykonuję jakiś kod', 'color: gold; text-transform: uppercase')
}

blue.addEventListener('click', infoBlue)
gold.addEventListener('click', infoGold)

# %% [markdown]
# 83. Delegacja zdarzeń

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link rel="stylesheet" href="style.css"
 
</head>

<body>
    <h1>DOM, Document, Window...</h1>

   
    <div>
        <div class='circle lime circle2'>
            <div class='circle blue'>
                <div class='circle gold circle2'></div>
            </div>
        </div>
    </div>

    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}

.blue {
	width: 400px;
	height: 400px;
	background-color: royalblue;
}

.gold {
	width: 250px;
	height: 250px;
	background-color: gold;
}

.purple {
	width: 100px;
	height: 100px;
	background-color: purple;
}

# %%
const allCircles = document.getElementsByClassName('.circle')
const gold = document.querySelector('.gold')
const lime = document.querySelector('.lime')

const newCircle = document.createElement('div')
newCircle.classList.add('circle', 'purple')
gold.append(newCircle)


//Odwołuje się do wszystkich kółek
// allCircles.forEach(circle => circle.addEventListener('click', () => console.log(circle)))

// console.log(allCircles.length);

// lime.addEventListener('click', e => {
//     if (e.target.matches('.circle2')) {
//         console.log(e.target)
//     }
// })

lime.addEventListener('click', e => {
    if (e.target.classList.contains('.circle2')) {
        console.log(e.target)
        console.log('test')
    }
})

# %% [markdown]
# 84. Stylowanie w JS

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title> MCC - JavaScript</title>
    <link ref="stylesheet" href="style.css"

</head>

<body>
    <h1>DOM, Document, Window...</h1>

    <div>
        <p>Jestem DIV-em!</p>
    </div>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
    box-sizing: border-box;
    margin: 0;
    padding: 0;
}

body {
    display: flex;
    justify-content: center;
    align-items: center;
    flex-direction: column;
    min-height: 100vh;
    font-family: 'Montserrat', sans-serif;
    background-color: #333;
    color: #fff;
}

.test {
    padding: 20px 40px;
    font-size: 48px;
    background-color: tomato;
    border-radius: 15px;
}

# %%
const div = document.querySelector('div')
console.log(div)

// div.style.fontSize = '48px'
// div.style.backgroundColor = 'tomato'
// div.style.padding = '20px 40px'
// div.style.borderRadius = '15px'

div.classList.add('test')

# %% [markdown]
# 85. Dodawanie i usuwanie klas

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>
    <h1>DOM, Document, Window...</h1>

    <div>
        <button class="add">dodaj</button>
        <button class="remove">usuń</button>
        <button class="toggle">toggle</button>
    </div>
    <p>Jestem paragrafem! 🙂</p>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	min-height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}

button {
	padding: 20px 40px;
	margin: 20px;
	background: none;
	color: #fff;
	font-size: 18px;
	text-transform: uppercase;
	border: 3px solid #ddd;
	border-radius: 8px;
	transition: background-color 0.3s, color 0.3s;
	cursor: pointer;
}

button:hover {
	background-color: #ddd;
	color: #000;
}

.test {
	margin-top: 20px;
	padding: 20px 40px;
	border-radius: 8px;
	background-color: #fff;
	color: #333;
}

# %%
const addBtn = document.querySelector('.add')
const removeBtn = document.querySelector('.remove')
const toggleBtn = document.querySelector('.toggle')
const text = document.querySelector('p')

// console.log(addBtn)
// console.log(removeBtn)
// console.log(toggleBtn)
// console.log(text)

// Dla zmiennej text przypisuje style text
const addClass = () => {
    text.classList.add('test')
}

const removeClass = () => {
    text.classList.remove('test')
}

const toggleClass = () => {
    text.classList.toggle('test')
}


addBtn.addEventListener('click', addClass)
removeBtn.addEventListener('click', removeClass)
toggleBtn.addEventListener('click', toggleClass)

# %% [markdown]
# 86. Zad. Stwórz listę i zmodyfikuj ją

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>
    <h1>DOM, Document, Window...</h1>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	min-height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}

button {
	padding: 20px 40px;
	margin: 20px;
	background: none;
	color: #fff;
	font-size: 18px;
	text-transform: uppercase;
	border: 3px solid #ddd;
	border-radius: 8px;
	transition: background-color 0.3s, color 0.3s;
	cursor: pointer;
}

button:hover {
	background-color: #ddd;
	color: #000;
}

# %%
const ulList = document.createElement('ul')
document.body.append(ulList)

const number = 11

for(let i=1; i<number; i++) {
    const liItem = document.createElement('li')
    liItem.textContent = i
    ulList.append(liItem)
}

const lastLi = ulList.querySelector('li:last-child')
lastLi.textContent = 'Ostatni element.'

lastLi.style.backgroundColor = 'royalblue'
lastLi.style.padding = '20px 40px'
lastLi.style.fontSize = '48px'

# %% [markdown]
# 87. Zad. Stwórz przyciski i podepnij nasłuchiwanie

# %%
<!DOCTYPE html>
<html lang='en'>

<head>
    <meta charset='UTF-8'>
    <meta http-equiv="X-UA-Compatibile" content='IE=edge'>
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JavaScript</title>
    <link rel="stylesheet" href="style.css"

</head>

<body>
    <div class="wrapper">
        <div class="buttons">
            <button class="btn btn1">🍔</button>
            <button class="btn btn2">🍕</button>
        </div>
        <div class="square"></div>
        <div class="text">
            <p class="p1">Paragraf 1</p>
            <p class="p2 show">Paragraf 2</p>
        </div>
    </div>
    
    <script src="./script.js"></script>
</body>
</html>

# %%
* {
	box-sizing: border-box;
	margin: 0;
	padding: 0;
}

body {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
	height: 100vh;
	font-family: 'Open Sans', sans-serif;
	color: #fff;
	background-color: #1e1d23;
	font-size: 36px;
}


.wrapper {
	display: flex;
	justify-content: center;
	align-items: center;
	flex-direction: column;
}

.p1,
.p2 {
	display: none;
}

.show {
	display: block;
}

.square {
	margin: 20px;
	width: 300px;
	height: 300px;
	background-color: gold;
}

button {
	padding: 20px 40px;
	margin: 20px;
	cursor: pointer;
	background: none;
	color: #fff;
	font-size: 18px;
	border: 3px solid #ddd;
	border-radius: 8px;
	transition: 0.3s;
	text-transform: uppercase;
}

button:hover {
	background-color: #ddd;
	color: #000;
}

# %%
const btn1 = document.querySelector('.btn1')
const btn2 = document.querySelector('.btn2')
const p1 = document.querySelector('.p1')
const p2 = document.querySelector('.p2')
const square = document.querySelector('.square')

const fun1 = () => {
    console.log('Cześć')
}

const fun2 = () => {
    square.style.background = 'tomato'
}

const fun3 = () => {
    square.style.background = 'royalblue'
}

const fun4 = () => {
    p1.classList.toggle('show')
    p2.classList.toggle('show')

    // if(p1.classList.contains('show')) {
    //     p1.classList.remove('show')
    //     p2.classList.add('show')
    // } else {
    //     p1.classList.add('show')
    //     p2.classList.remove('show')
    // }

}

btn1.addEventListener('click', fun1)
square.addEventListener('mouseenter', fun2)
square.addEventListener('mouseleave', fun3)
btn2.addEventListener('click', fun4)
